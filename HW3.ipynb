# %% [markdown]
# Реализуйте алгоритм GAIL на среде Mountain Car. Перед этим сгенерируйте экспертные данные (из детерминированной стратегии с первой практики). Хорошей идеей будет добавить в state (observation) синус и косинус от временной метки t для лучшего обучения.

# %%
import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
from torch.distributions.categorical import Categorical
import torch.optim as optim
import torch.nn.functional as F

from collections import deque
import random

# %%
# Создание среды
TIME_LIMIT = 250
env = gym.wrappers.TimeLimit(
    gym.make("MountainCar-v0"),
    max_episode_steps=TIME_LIMIT + 1,
)

# Детерминированная стратегия из первой практики
def expert_policy(obs, t):
    position, velocity = obs

    if t <= 50:
        return 0  # Влево
    elif t <= 100:
        return 2  # Вправо
    elif t <= 150:
        return 0  # Влево
    elif t <= 200:
        return 2  # Вправо
    else:
        return 2  # Вправо

# Генерация экспертных данных
def generate_expert_data(env, expert_policy, num_episodes=100):
    states = []
    actions = []

    for episode in range(num_episodes):
        obs, _ = env.reset()
        done = False
        t = 0  # Временная метка

        while not done:
            # Выбираем действие с помощью экспертной стратегии
            action = expert_policy(obs, t)

            # Совершаем шаг в среде
            next_obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated

            # Дополняем состояние синусом и косинусом временной метки t
            extended_state = np.append(obs, [np.sin(t), np.cos(t)])
            states.append(extended_state)
            actions.append(action)

            # Обновляем состояние и временную метку
            obs = next_obs
            t += 1

    return np.array(states, dtype=np.float32), np.array(actions, dtype=np.int64)

# Генерируем данные
print("Generating expert data...")
states, actions = generate_expert_data(env, expert_policy, num_episodes=100)

# Вывод информации о данных
print("Количество данных в states:", len(states))
print("Количество данных в actions:", len(actions))
# Out:
# Generating expert data...
# Количество данных в states: 17036
# Количество данных в actions: 17036

# %%
def test_policy(env, expert_policy, num_episodes=10):
    total_rewards = []
    episode_lengths = []

    for episode in range(num_episodes):
        obs, _ = env.reset()
        done = False
        total_reward = 0
        t = 0

        while not done:
            # Используем экспертную стратегию для выбора действия
            action = expert_policy(obs, t)
            obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            total_reward += reward
            t += 1

        total_rewards.append(total_reward)
        episode_lengths.append(t)
        print(f"Episode {episode + 1}: Total Reward = {total_reward}, Steps = {t}")

    avg_reward = np.mean(total_rewards)
    avg_length = np.mean(episode_lengths)
    print(f"Average Reward: {avg_reward:.2f}, Average Episode Length: {avg_length:.2f}")

# Тестируем стратегию
print("Testing policy...")
test_policy(env, expert_policy, num_episodes=10)
# Out:
# Testing policy...
# Episode 1: Total Reward = -184.0, Steps = 184
# Episode 2: Total Reward = -185.0, Steps = 185
# Episode 3: Total Reward = -184.0, Steps = 184
# Episode 4: Total Reward = -184.0, Steps = 184
# Episode 5: Total Reward = -184.0, Steps = 184
# Episode 6: Total Reward = -184.0, Steps = 184
# Episode 7: Total Reward = -184.0, Steps = 184
# Episode 8: Total Reward = -184.0, Steps = 184
# Episode 9: Total Reward = -100.0, Steps = 100
# Episode 10: Total Reward = -97.0, Steps = 97
# Average Reward: -167.00, Average Episode Length: 167.00

# %%
# Размерности для среды MountainCar
obs_dim = 4  # 2 исходных признака + sin(t) + cos(t)
act_dim = env.action_space.n  # Количество действий в среде

# Копирование экспертных данных
expert_obs = np.copy(states)  # Состояния с добавленными sin(t) и cos(t)
expert_acts = np.copy(actions)  # Действия эксперта

print(f"Размерность состояний (obs_dim): {obs_dim}")
print(f"Размерность действий (act_dim): {act_dim}")
# Out:
# Размерность состояний (obs_dim): 4
# Размерность действий (act_dim): 3

# %%
class Policy(nn.Module):
    def __init__(self, obs_dim, act_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_dim, 64),
            nn.ReLU(),
            nn.Linear(64, act_dim)
        )

    def forward(self, obs):
        # Преобразуем входные данные в тензор, если они не являются тензором
        if not isinstance(obs, torch.Tensor):
            obs = torch.tensor(obs, dtype=torch.float32)
        logits = self.net(obs)
        return Categorical(logits=logits)

    def get_action(self, obs):
        # Получаем распределение действий
        dist = self.forward(obs)
        # Выбираем действие
        action = dist.sample()
        return action.item()

    def get_log_prob(self, obs, actions):
        # Получаем распределение действий
        dist = self.forward(obs)
        # Возвращаем логарифм вероятности выбранных действий
        return dist.log_prob(actions)

# %%
class Discriminator(nn.Module):
    def __init__(self, obs_dim, act_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_dim + act_dim, 64), nn.ReLU(),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )

    def forward(self, obs, act):
        # Преобразуем действия в one-hot encoding
        act_onehot = F.one_hot(act, num_classes=3).float()  # num_classes = 3 для MountainCar-v0
        
        # Объединяем состояние и one-hot encoded действия
        x = torch.cat([obs, act_onehot], dim=1)
        
        # Пропускаем через сеть
        return self.net(x)

# %%
class TrajectoryBuffer:
    def __init__(self):
        # Инициализация списков для хранения данных
        self.obs, self.acts, self.rews = [], [], []

    def store(self, o, a, r):
        # Добавление состояния, действия и награды в буфер
        self.obs.append(o)
        self.acts.append(a)
        self.rews.append(r)

    def get(self):
        # Преобразование данных в тензоры PyTorch
        obs_tensor = torch.tensor(np.array(self.obs), dtype=torch.float32)
        acts_tensor = torch.tensor(np.array(self.acts), dtype=torch.long)
        rews_tensor = torch.tensor(np.array(self.rews), dtype=torch.float32)
        
        # Очистка буфера после извлечения данных
        self.clear()
        
        return obs_tensor, acts_tensor, rews_tensor

    def clear(self):
        # Очистка буфера
        self.obs, self.acts, self.rews = [], [], []

# %%
env = gym.make("MountainCar-v0", )
policy = Policy(obs_dim, act_dim)
discrim = Discriminator(obs_dim, act_dim)

policy_opt = optim.Adam(policy.parameters(), lr=1e-3)
discrim_opt = optim.Adam(discrim.parameters(), lr=1e-3)

# %%
for epoch in range(3000):
    buf = TrajectoryBuffer()
    obs, _ = env.reset()
    done = False
    total_reward = 0
    t = 0  # Временная метка

    while not done:
        # Добавляем sin(t) и cos(t) к состоянию
        augmented_obs = np.append(obs, [np.sin(t), np.cos(t)])
        
        # Преобразуем состояние в тензор
        obs_tensor = torch.tensor(augmented_obs, dtype=torch.float32).unsqueeze(0)
        
        # Получаем действие от политики
        action = policy.get_action(obs_tensor)
        
        # Совершаем шаг в среде
        next_obs, _, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        
        # Сохраняем данные в буфер
        buf.store(augmented_obs, action, 0)
        
        # Обновляем временную метку и состояние
        t += 1
        obs = next_obs

    # Получаем данные из буфера
    agent_obs, agent_acts, _ = buf.get()

    # Выбираем случайные данные эксперта
    idxs = np.random.choice(len(expert_obs), len(agent_obs), replace=False)
    exp_obs = torch.tensor(expert_obs[idxs], dtype=torch.float32)
    exp_acts = torch.tensor(expert_acts[idxs], dtype=torch.long)

    # Обучение дискриминатора
    for _ in range(2):
        discrim_opt.zero_grad()

        # Предсказания дискриминатора
        agent_preds = discrim(agent_obs, agent_acts)
        expert_preds = discrim(exp_obs, exp_acts)

        # Бинарная кросс-энтропия
        disc_loss = -(torch.log(expert_preds + 1e-8).mean() - torch.log(1 - agent_preds + 1e-8).mean())

        disc_loss.backward()
        discrim_opt.step()

    # Получение награды от дискриминатора
    with torch.no_grad():
        rewards = -torch.log(1 - discrim(agent_obs, agent_acts) + 1e-8)

    # Обучение политики
    policy_opt.zero_grad()

    # Логарифмы вероятностей выбранных действий
    log_probs = policy.get_log_prob(agent_obs, agent_acts)

    # Потери для стратегии
    loss = -(rewards * log_probs).mean()

    loss.backward()
    policy_opt.step()

    # Вывод информации каждые 10 эпох
    if epoch % 10 == 0:
        print(f"Epoch {epoch}: GAIL Loss {loss.item():.3f}, Disc Loss {disc_loss.item():.3f}")
# Out:
# Epoch 0: GAIL Loss 0.757, Disc Loss 0.004
# Epoch 10: GAIL Loss 0.941, Disc Loss -0.305
# Epoch 20: GAIL Loss 1.181, Disc Loss -0.667
# Epoch 30: GAIL Loss 1.534, Disc Loss -1.127
# Epoch 40: GAIL Loss 2.093, Disc Loss -1.754
# Epoch 50: GAIL Loss 2.956, Disc Loss -2.598
# Epoch 60: GAIL Loss 4.026, Disc Loss -3.692
# Epoch 70: GAIL Loss 5.588, Disc Loss -5.079
# Epoch 80: GAIL Loss 7.367, Disc Loss -6.774
# Epoch 90: GAIL Loss 9.633, Disc Loss -8.740
# Epoch 100: GAIL Loss 11.983, Disc Loss -11.140
# Epoch 110: GAIL Loss 14.700, Disc Loss -13.857
# Epoch 120: GAIL Loss 18.668, Disc Loss -17.359
# Epoch 130: GAIL Loss 18.808, Disc Loss -18.421
# Epoch 140: GAIL Loss 19.466, Disc Loss -18.421
# Epoch 150: GAIL Loss 19.412, Disc Loss -18.421
# Epoch 160: GAIL Loss 18.379, Disc Loss -18.421
# Epoch 170: GAIL Loss 18.834, Disc Loss -18.421
# Epoch 180: GAIL Loss 18.991, Disc Loss -18.421
# Epoch 190: GAIL Loss 17.707, Disc Loss -18.421
# Epoch 200: GAIL Loss 19.062, Disc Loss -18.421
# Epoch 210: GAIL Loss 18.248, Disc Loss -18.421
# Epoch 220: GAIL Loss 17.653, Disc Loss -18.421
# Epoch 230: GAIL Loss 18.306, Disc Loss -18.421
# Epoch 240: GAIL Loss 17.991, Disc Loss -18.421
# Epoch 250: GAIL Loss 18.547, Disc Loss -18.421
# Epoch 260: GAIL Loss 18.750, Disc Loss -18.421
# Epoch 270: GAIL Loss 18.295, Disc Loss -18.408
# Epoch 280: GAIL Loss 17.522, Disc Loss -18.421
# Epoch 290: GAIL Loss 18.500, Disc Loss -18.421
# Epoch 300: GAIL Loss 17.759, Disc Loss -18.421
# Epoch 310: GAIL Loss 18.897, Disc Loss -18.421
# Epoch 320: GAIL Loss 19.295, Disc Loss -18.421
# Epoch 330: GAIL Loss 18.761, Disc Loss -18.421
# Epoch 340: GAIL Loss 19.148, Disc Loss -18.421
# Epoch 350: GAIL Loss 19.063, Disc Loss -18.421
# Epoch 360: GAIL Loss 18.634, Disc Loss -18.421
# Epoch 370: GAIL Loss 19.581, Disc Loss -18.421
# Epoch 380: GAIL Loss 19.013, Disc Loss -18.421
# Epoch 390: GAIL Loss 19.286, Disc Loss -18.421
# Epoch 400: GAIL Loss 18.611, Disc Loss -18.421
# Epoch 410: GAIL Loss 19.373, Disc Loss -18.421
# Epoch 420: GAIL Loss 19.820, Disc Loss -18.421
# Epoch 430: GAIL Loss 19.773, Disc Loss -18.421
# Epoch 440: GAIL Loss 19.163, Disc Loss -18.421
# Epoch 450: GAIL Loss 18.294, Disc Loss -18.421
# Epoch 460: GAIL Loss 19.131, Disc Loss -18.421
# Epoch 470: GAIL Loss 18.776, Disc Loss -18.421
# Epoch 480: GAIL Loss 18.210, Disc Loss -18.421
# Epoch 490: GAIL Loss 18.885, Disc Loss -18.421
# Epoch 500: GAIL Loss 18.902, Disc Loss -18.421
# Epoch 510: GAIL Loss 18.256, Disc Loss -18.421
# Epoch 520: GAIL Loss 19.077, Disc Loss -18.421
# Epoch 530: GAIL Loss 19.454, Disc Loss -18.421
# Epoch 540: GAIL Loss 19.597, Disc Loss -18.421
# Epoch 550: GAIL Loss 19.384, Disc Loss -18.421
# Epoch 560: GAIL Loss 19.385, Disc Loss -18.421
# Epoch 570: GAIL Loss 19.303, Disc Loss -18.421
# Epoch 580: GAIL Loss 18.475, Disc Loss -18.421
# Epoch 590: GAIL Loss 18.919, Disc Loss -18.421
# Epoch 600: GAIL Loss 18.631, Disc Loss -18.421
# Epoch 610: GAIL Loss 20.115, Disc Loss -18.421
# Epoch 620: GAIL Loss 19.536, Disc Loss -18.421
# Epoch 630: GAIL Loss 19.283, Disc Loss -18.421
# Epoch 640: GAIL Loss 19.290, Disc Loss -18.421
# Epoch 650: GAIL Loss 19.344, Disc Loss -18.421
# Epoch 660: GAIL Loss 19.255, Disc Loss -18.421
# Epoch 670: GAIL Loss 19.373, Disc Loss -18.421
# Epoch 680: GAIL Loss 18.685, Disc Loss -18.421
# Epoch 690: GAIL Loss 19.125, Disc Loss -18.421
# Epoch 700: GAIL Loss 18.983, Disc Loss -18.421
# Epoch 710: GAIL Loss 18.585, Disc Loss -18.421
# Epoch 720: GAIL Loss 18.217, Disc Loss -18.421
# Epoch 730: GAIL Loss 18.783, Disc Loss -18.421
# Epoch 740: GAIL Loss 18.302, Disc Loss -18.421
# Epoch 750: GAIL Loss 18.686, Disc Loss -18.421
# Epoch 760: GAIL Loss 19.207, Disc Loss -18.421
# Epoch 770: GAIL Loss 19.265, Disc Loss -18.421
# Epoch 780: GAIL Loss 18.564, Disc Loss -18.421
# Epoch 790: GAIL Loss 18.783, Disc Loss -18.421
# Epoch 800: GAIL Loss 19.502, Disc Loss -18.421
# Epoch 810: GAIL Loss 18.909, Disc Loss -18.421
# Epoch 820: GAIL Loss 19.538, Disc Loss -18.421
# Epoch 830: GAIL Loss 18.655, Disc Loss -18.421
# Epoch 840: GAIL Loss 19.345, Disc Loss -18.421
# Epoch 850: GAIL Loss 19.350, Disc Loss -18.421
# Epoch 860: GAIL Loss 19.144, Disc Loss -18.421
# Epoch 870: GAIL Loss 17.993, Disc Loss -18.421
# Epoch 880: GAIL Loss 18.646, Disc Loss -18.421
# Epoch 890: GAIL Loss 18.310, Disc Loss -18.421
# Epoch 900: GAIL Loss 16.852, Disc Loss -18.421
# Epoch 910: GAIL Loss 18.483, Disc Loss -18.421
# Epoch 920: GAIL Loss 18.190, Disc Loss -18.421
# Epoch 930: GAIL Loss 18.102, Disc Loss -18.421
# Epoch 940: GAIL Loss 18.206, Disc Loss -18.421
# Epoch 950: GAIL Loss 17.242, Disc Loss -18.421
# Epoch 960: GAIL Loss 18.183, Disc Loss -18.421
# Epoch 970: GAIL Loss 17.805, Disc Loss -18.421
# Epoch 980: GAIL Loss 17.955, Disc Loss -18.421
# Epoch 990: GAIL Loss 17.549, Disc Loss -18.421
# Epoch 1000: GAIL Loss 16.741, Disc Loss -18.421
# Epoch 1010: GAIL Loss 16.602, Disc Loss -18.421
# Epoch 1020: GAIL Loss 17.922, Disc Loss -18.421
# Epoch 1030: GAIL Loss 17.382, Disc Loss -18.421
# Epoch 1040: GAIL Loss 19.119, Disc Loss -18.421
# Epoch 1050: GAIL Loss 17.984, Disc Loss -18.421
# Epoch 1060: GAIL Loss 19.604, Disc Loss -18.421
# Epoch 1070: GAIL Loss 19.058, Disc Loss -18.421
# Epoch 1080: GAIL Loss 18.825, Disc Loss -18.421
# Epoch 1090: GAIL Loss 19.282, Disc Loss -18.421
# Epoch 1100: GAIL Loss 19.188, Disc Loss -18.421
# Epoch 1110: GAIL Loss 19.499, Disc Loss -18.421
# Epoch 1120: GAIL Loss 20.040, Disc Loss -18.421
# Epoch 1130: GAIL Loss 18.009, Disc Loss -18.421
# Epoch 1140: GAIL Loss 18.289, Disc Loss -18.421
# Epoch 1150: GAIL Loss 19.428, Disc Loss -18.421
# Epoch 1160: GAIL Loss 18.209, Disc Loss -18.421
# Epoch 1170: GAIL Loss 18.661, Disc Loss -18.421
# Epoch 1180: GAIL Loss 18.068, Disc Loss -18.421
# Epoch 1190: GAIL Loss 18.110, Disc Loss -18.421
# Epoch 1200: GAIL Loss 18.625, Disc Loss -18.421
# Epoch 1210: GAIL Loss 19.053, Disc Loss -18.421
# Epoch 1220: GAIL Loss 17.814, Disc Loss -18.421
# Epoch 1230: GAIL Loss 16.755, Disc Loss -18.421
# Epoch 1240: GAIL Loss 17.439, Disc Loss -18.421
# Epoch 1250: GAIL Loss 17.595, Disc Loss -18.421
# Epoch 1260: GAIL Loss 17.941, Disc Loss -18.421
# Epoch 1270: GAIL Loss 17.859, Disc Loss -18.421
# Epoch 1280: GAIL Loss 17.108, Disc Loss -18.421
# Epoch 2230: GAIL Loss 18.999, Disc Loss -18.421
# Epoch 2240: GAIL Loss 18.371, Disc Loss -18.421
# Epoch 2250: GAIL Loss 18.078, Disc Loss -18.421
# Epoch 2260: GAIL Loss 18.634, Disc Loss -18.421
# Epoch 2270: GAIL Loss 18.283, Disc Loss -18.421
# Epoch 2280: GAIL Loss 18.720, Disc Loss -18.421
# Epoch 2290: GAIL Loss 18.800, Disc Loss -18.421
# Epoch 2300: GAIL Loss 18.217, Disc Loss -18.421
# Epoch 2310: GAIL Loss 17.282, Disc Loss -18.421
# Epoch 2320: GAIL Loss 17.359, Disc Loss -18.421
# Epoch 2330: GAIL Loss 17.686, Disc Loss -18.421
# Epoch 2340: GAIL Loss 17.969, Disc Loss -18.421
# Epoch 2350: GAIL Loss 18.062, Disc Loss -18.421
# Epoch 2360: GAIL Loss 17.997, Disc Loss -18.421
# Epoch 2370: GAIL Loss 18.342, Disc Loss -18.421
# Epoch 2380: GAIL Loss 18.120, Disc Loss -18.421
# Epoch 2390: GAIL Loss 18.096, Disc Loss -18.421
# Epoch 2400: GAIL Loss 18.400, Disc Loss -18.421
# Epoch 2410: GAIL Loss 18.240, Disc Loss -18.421
# Epoch 2420: GAIL Loss 19.185, Disc Loss -18.421
# Epoch 2430: GAIL Loss 18.422, Disc Loss -18.421
# Epoch 2440: GAIL Loss 18.302, Disc Loss -18.421
# Epoch 2450: GAIL Loss 17.072, Disc Loss -18.421
# Epoch 2460: GAIL Loss 17.888, Disc Loss -18.421
# Epoch 2470: GAIL Loss 16.859, Disc Loss -18.421
# Epoch 2480: GAIL Loss 18.587, Disc Loss -18.421
# Epoch 2490: GAIL Loss 18.816, Disc Loss -18.421
# Epoch 2500: GAIL Loss 17.079, Disc Loss -18.421
# Epoch 2510: GAIL Loss 17.791, Disc Loss -18.421
# Epoch 2520: GAIL Loss 18.002, Disc Loss -18.421
# Epoch 2530: GAIL Loss 17.140, Disc Loss -18.421
# Epoch 2540: GAIL Loss 17.858, Disc Loss -18.421
# Epoch 2550: GAIL Loss 16.945, Disc Loss -18.421
# Epoch 2560: GAIL Loss 18.211, Disc Loss -18.421
# Epoch 2570: GAIL Loss 17.701, Disc Loss -18.421
# Epoch 2580: GAIL Loss 17.933, Disc Loss -18.421
# Epoch 2590: GAIL Loss 17.131, Disc Loss -18.421
# Epoch 2600: GAIL Loss 17.618, Disc Loss -18.421
# Epoch 2610: GAIL Loss 17.680, Disc Loss -18.421
# Epoch 2620: GAIL Loss 16.573, Disc Loss -18.421
# Epoch 2630: GAIL Loss 17.030, Disc Loss -18.421
# Epoch 2640: GAIL Loss 16.643, Disc Loss -18.421
# Epoch 2650: GAIL Loss 15.710, Disc Loss -18.421
# Epoch 2660: GAIL Loss 16.667, Disc Loss -18.421
# Epoch 2670: GAIL Loss 16.960, Disc Loss -18.421
# Epoch 2680: GAIL Loss 17.390, Disc Loss -18.421
# Epoch 2690: GAIL Loss 16.707, Disc Loss -18.421
# Epoch 2700: GAIL Loss 16.057, Disc Loss -18.421
# Epoch 2710: GAIL Loss 16.975, Disc Loss -18.421
# Epoch 2720: GAIL Loss 17.294, Disc Loss -18.421
# Epoch 2730: GAIL Loss 16.831, Disc Loss -18.421
# Epoch 2740: GAIL Loss 15.735, Disc Loss -18.421
# Epoch 2750: GAIL Loss 16.682, Disc Loss -18.421
# Epoch 2760: GAIL Loss 17.046, Disc Loss -18.421
# Epoch 2770: GAIL Loss 15.282, Disc Loss -18.421
# Epoch 2780: GAIL Loss 16.307, Disc Loss -18.421
# Epoch 2790: GAIL Loss 16.067, Disc Loss -18.421
# Epoch 2800: GAIL Loss 16.985, Disc Loss -18.421
# Epoch 2810: GAIL Loss 16.413, Disc Loss -18.421
# Epoch 2820: GAIL Loss 15.972, Disc Loss -18.421
# Epoch 2830: GAIL Loss 17.762, Disc Loss -18.421
# Epoch 2840: GAIL Loss 16.767, Disc Loss -18.421
# Epoch 2850: GAIL Loss 15.961, Disc Loss -18.421
# Epoch 2860: GAIL Loss 17.013, Disc Loss -18.421
# Epoch 2870: GAIL Loss 16.300, Disc Loss -18.421
# Epoch 2880: GAIL Loss 16.472, Disc Loss -18.421
# Epoch 2890: GAIL Loss 16.730, Disc Loss -18.421
# Epoch 2900: GAIL Loss 16.135, Disc Loss -18.421
# Epoch 2910: GAIL Loss 17.166, Disc Loss -18.421
# Epoch 2920: GAIL Loss 15.936, Disc Loss -18.421
# Epoch 2930: GAIL Loss 16.867, Disc Loss -18.421
# Epoch 2940: GAIL Loss 16.498, Disc Loss -18.421
# Epoch 2950: GAIL Loss 16.695, Disc Loss -18.421
# Epoch 2960: GAIL Loss 18.222, Disc Loss -18.421
# Epoch 2970: GAIL Loss 17.380, Disc Loss -18.421
# Epoch 2980: GAIL Loss 16.824, Disc Loss -18.421
# Epoch 2990: GAIL Loss 16.065, Disc Loss -18.421

# %% [markdown]
# Протестируйте ваш алгоритм

# %%
for episode in range(10):
    obs, _ = env.reset()  # Получаем начальное состояние (игнорируем info)
    done = False
    total_reward = 0
    t = 0  # Временная метка

    while not done:
        # Добавляем sin(t) и cos(t) к состоянию
        augmented_obs = np.append(obs, [np.sin(t), np.cos(t)])
        
        # Преобразуем состояние в тензор
        obs_tensor = torch.tensor(augmented_obs, dtype=torch.float32).unsqueeze(0)
        
        # Получаем действие от политики
        action = policy.get_action(obs_tensor)
        
        # Совершаем шаг в среде
        next_obs, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        
        # Обновляем состояние и награду
        obs = next_obs
        total_reward += reward
        t += 1

    print(f"Episode {episode + 1}: Total Reward = {total_reward}")
env.close()
# Out:
# Episode 1: Total Reward = -200.0
# Episode 2: Total Reward = -200.0
# Episode 3: Total Reward = -200.0
# Episode 4: Total Reward = -200.0
# Episode 5: Total Reward = -200.0
# Episode 6: Total Reward = -200.0
# Episode 7: Total Reward = -200.0
# Episode 8: Total Reward = -200.0
# Episode 9: Total Reward = -200.0
# Episode 10: Total Reward = -200.0
