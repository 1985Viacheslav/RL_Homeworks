# %% [markdown]
# Реализуйте алгоритм GAIL на среде Mountain Car. Перед этим сгенерируйте экспертные данные (из детерминированной стратегии с первой практики). Хорошей идеей будет добавить в state (observation) синус и косинус от временной метки t для лучшего обучения.

# %%
import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
from torch.distributions.categorical import Categorical
import torch.optim as optim
import torch.nn.functional as F

from collections import deque
import random

# %%
def generate_expert_data(env, expert_policy, num_episodes=100):
    states = []
    actions = []
    
    for episode in range(num_episodes):
        # env.reset() теперь возвращает кортеж (state, info)
        state, _ = env.reset()
        done = False
        t = 0  # Временная метка
        
        while not done:
            # Используем экспертную стратегию для текущего состояния
            action = expert_policy(state)
            
            # Совершаем шаг в среде
            next_state, reward, terminated, truncated, info = env.step(action)
            
            # Состояние считается завершенным, если terminated или truncated
            done = terminated or truncated
            
            # Дополняем состояние синусом и косинусом временной метки t
            if isinstance(state, np.ndarray):  # Убедимся, что state — массив
                extended_state = np.append(state, [np.sin(t), np.cos(t)])
                states.append(extended_state)
            else:
                raise ValueError("State is not a valid array")
            
            actions.append(action)
            state = next_state
            t += 1  # Увеличиваем временную метку
    
    return np.array(states), np.array(actions)

def expert_policy(state):
    # Экспертная стратегия: двигаться вправо, если скорость положительная, иначе влево
    if isinstance(state, np.ndarray):  # Убедимся, что state — массив
        velocity = state[1]
        return 0 if velocity < 0 else 2
    else:
        raise ValueError("State is not a valid array")

# Создаем среду MountainCar
env = gym.make("MountainCar-v0", render_mode="rgb_array")  # Убедитесь, что используете версию Gym >= 0.26

# Генерация экспертных данных
states, actions = generate_expert_data(env, expert_policy)

print("Количество данных в states:", len(states))
print("Количество данных в actions:", len(actions))
# Out:
# Количество данных в states: 11934
# Количество данных в actions: 11934

# %%
# Размерности для среды MountainCar
obs_dim = 4  # 2 исходных признака + sin(t) + cos(t)
act_dim = env.action_space.n  # Количество действий в среде

# Копирование экспертных данных
expert_obs = np.copy(states)  # Состояния с добавленными sin(t) и cos(t)
expert_acts = np.copy(actions)  # Действия эксперта

print(f"Размерность состояний (obs_dim): {obs_dim}")
print(f"Размерность действий (act_dim): {act_dim}")
# Out:
# Размерность состояний (obs_dim): 4
# Размерность действий (act_dim): 3

# %%
class Policy(nn.Module):
    def __init__(self, obs_dim, act_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_dim, 64),
            nn.ReLU(),
            nn.Linear(64, act_dim)
        )

    def forward(self, obs):
        # Преобразуем входные данные в тензор, если они не являются тензором
        if not isinstance(obs, torch.Tensor):
            obs = torch.tensor(obs, dtype=torch.float32)
        logits = self.net(obs)
        return Categorical(logits=logits)

    def get_action(self, obs):
        # Получаем распределение действий
        dist = self.forward(obs)
        # Выбираем действие
        action = dist.sample()
        return action.item()

    def get_log_prob(self, obs, actions):
        # Получаем распределение действий
        dist = self.forward(obs)
        # Возвращаем логарифм вероятности выбранных действий
        return dist.log_prob(actions)

# %%
class Discriminator(nn.Module):
    def __init__(self, obs_dim, act_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_dim + act_dim, 64), nn.ReLU(),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )

    def forward(self, obs, act):
        # Преобразуем действия в one-hot encoding
        act_onehot = F.one_hot(act, num_classes=3).float()  # num_classes = 3 для MountainCar-v0
        
        # Объединяем состояние и one-hot encoded действия
        x = torch.cat([obs, act_onehot], dim=1)
        
        # Пропускаем через сеть
        return self.net(x)

# %%
class TrajectoryBuffer:
    def __init__(self):
        # Инициализация списков для хранения данных
        self.obs, self.acts, self.rews = [], [], []

    def store(self, o, a, r):
        # Добавление состояния, действия и награды в буфер
        self.obs.append(o)
        self.acts.append(a)
        self.rews.append(r)

    def get(self):
        # Преобразование данных в тензоры PyTorch
        obs_tensor = torch.tensor(np.array(self.obs), dtype=torch.float32)
        acts_tensor = torch.tensor(np.array(self.acts), dtype=torch.long)
        rews_tensor = torch.tensor(np.array(self.rews), dtype=torch.float32)
        
        # Очистка буфера после извлечения данных
        self.clear()
        
        return obs_tensor, acts_tensor, rews_tensor

    def clear(self):
        # Очистка буфера
        self.obs, self.acts, self.rews = [], [], []

# %%
env = gym.make("MountainCar-v0", )
policy = Policy(obs_dim, act_dim)
discrim = Discriminator(obs_dim, act_dim)

policy_opt = optim.Adam(policy.parameters(), lr=1e-3)
discrim_opt = optim.Adam(discrim.parameters(), lr=1e-3)

# %%
for epoch in range(3000):
    buf = TrajectoryBuffer()
    obs, _ = env.reset()
    done = False
    total_reward = 0
    t = 0  # Временная метка

    while not done:
        # Добавляем sin(t) и cos(t) к состоянию
        augmented_obs = np.append(obs, [np.sin(t), np.cos(t)])
        
        # Преобразуем состояние в тензор
        obs_tensor = torch.tensor(augmented_obs, dtype=torch.float32).unsqueeze(0)
        
        # Получаем действие от политики
        action = policy.get_action(obs_tensor)
        
        # Совершаем шаг в среде
        next_obs, _, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        
        # Сохраняем данные в буфер
        buf.store(augmented_obs, action, 0)
        
        # Обновляем временную метку и состояние
        t += 1
        obs = next_obs

    # Получаем данные из буфера
    agent_obs, agent_acts, _ = buf.get()

    # Выбираем случайные данные эксперта
    idxs = np.random.choice(len(expert_obs), len(agent_obs), replace=False)
    exp_obs = torch.tensor(expert_obs[idxs], dtype=torch.float32)
    exp_acts = torch.tensor(expert_acts[idxs], dtype=torch.long)

    # Обучение дискриминатора
    for _ in range(2):
        discrim_opt.zero_grad()

        # Предсказания дискриминатора
        agent_preds = discrim(agent_obs, agent_acts)
        expert_preds = discrim(exp_obs, exp_acts)

        # Бинарная кросс-энтропия
        disc_loss = -(torch.log(expert_preds + 1e-8).mean() + torch.log(1 - agent_preds + 1e-8).mean())

        disc_loss.backward()
        discrim_opt.step()

    # Получение награды от дискриминатора
    with torch.no_grad():
        rewards = -torch.log(1 - discrim(agent_obs, agent_acts) + 1e-8)

    # Обучение политики
    policy_opt.zero_grad()

    # Логарифмы вероятностей выбранных действий
    log_probs = policy.get_log_prob(agent_obs, agent_acts)

    # Потери для стратегии
    loss = -(rewards * log_probs).mean()

    loss.backward()
    policy_opt.step()

    # Вывод информации каждые 10 эпох
    if epoch % 10 == 0:
        print(f"Epoch {epoch}: GAIL Loss {loss.item():.3f}, Disc Loss {disc_loss.item():.3f}")
# Out:
# Epoch 0: GAIL Loss 0.825, Disc Loss 1.404
# Epoch 10: GAIL Loss 0.749, Disc Loss 1.381
# Epoch 20: GAIL Loss 0.727, Disc Loss 1.348
# Epoch 30: GAIL Loss 0.715, Disc Loss 1.344
# Epoch 40: GAIL Loss 0.695, Disc Loss 1.281
# Epoch 50: GAIL Loss 0.706, Disc Loss 1.300
# Epoch 60: GAIL Loss 0.669, Disc Loss 1.232
# Epoch 70: GAIL Loss 0.660, Disc Loss 1.226
# Epoch 80: GAIL Loss 0.646, Disc Loss 1.174
# Epoch 90: GAIL Loss 0.617, Disc Loss 1.166
# Epoch 100: GAIL Loss 0.638, Disc Loss 1.182
# Epoch 110: GAIL Loss 0.625, Disc Loss 1.173
# Epoch 120: GAIL Loss 0.631, Disc Loss 1.185
# Epoch 130: GAIL Loss 0.566, Disc Loss 1.118
# Epoch 140: GAIL Loss 0.599, Disc Loss 1.143
# Epoch 150: GAIL Loss 0.586, Disc Loss 1.126
# Epoch 160: GAIL Loss 0.568, Disc Loss 1.096
# Epoch 170: GAIL Loss 0.511, Disc Loss 1.027
# Epoch 180: GAIL Loss 0.556, Disc Loss 1.148
# Epoch 190: GAIL Loss 0.525, Disc Loss 1.028
# Epoch 200: GAIL Loss 0.498, Disc Loss 0.984
# Epoch 210: GAIL Loss 0.498, Disc Loss 1.040
# Epoch 220: GAIL Loss 0.493, Disc Loss 1.017
# Epoch 230: GAIL Loss 0.492, Disc Loss 0.972
# Epoch 240: GAIL Loss 0.472, Disc Loss 0.977
# Epoch 250: GAIL Loss 0.481, Disc Loss 0.958
# Epoch 260: GAIL Loss 0.479, Disc Loss 0.890
# Epoch 270: GAIL Loss 0.424, Disc Loss 0.895
# Epoch 280: GAIL Loss 0.441, Disc Loss 0.935
# Epoch 290: GAIL Loss 0.349, Disc Loss 0.862
# Epoch 300: GAIL Loss 0.342, Disc Loss 0.831
# Epoch 310: GAIL Loss 0.421, Disc Loss 0.912
# Epoch 320: GAIL Loss 0.400, Disc Loss 0.809
# Epoch 330: GAIL Loss 0.459, Disc Loss 0.885
# Epoch 340: GAIL Loss 0.443, Disc Loss 0.860
# Epoch 350: GAIL Loss 0.418, Disc Loss 0.891
# Epoch 360: GAIL Loss 0.390, Disc Loss 0.805
# Epoch 370: GAIL Loss 0.385, Disc Loss 0.807
# Epoch 380: GAIL Loss 0.510, Disc Loss 0.937
# Epoch 390: GAIL Loss 0.331, Disc Loss 0.755
# Epoch 400: GAIL Loss 0.398, Disc Loss 0.875
# Epoch 410: GAIL Loss 0.306, Disc Loss 0.794
# Epoch 420: GAIL Loss 0.378, Disc Loss 0.729
# Epoch 430: GAIL Loss 0.583, Disc Loss 0.984
# Epoch 440: GAIL Loss 0.396, Disc Loss 0.805
# Epoch 450: GAIL Loss 0.450, Disc Loss 0.878
# Epoch 460: GAIL Loss 0.306, Disc Loss 0.728
# Epoch 470: GAIL Loss 0.306, Disc Loss 0.764
# Epoch 480: GAIL Loss 0.255, Disc Loss 0.691
# Epoch 490: GAIL Loss 0.344, Disc Loss 0.739
# Epoch 500: GAIL Loss 0.348, Disc Loss 0.732
# Epoch 510: GAIL Loss 0.280, Disc Loss 0.628
# Epoch 520: GAIL Loss 0.365, Disc Loss 0.745
# Epoch 530: GAIL Loss 0.351, Disc Loss 0.747
# Epoch 540: GAIL Loss 0.343, Disc Loss 0.715
# Epoch 550: GAIL Loss 0.315, Disc Loss 0.754
# Epoch 560: GAIL Loss 0.637, Disc Loss 1.007
# Epoch 570: GAIL Loss 0.330, Disc Loss 0.730
# Epoch 580: GAIL Loss 0.264, Disc Loss 0.672
# Epoch 590: GAIL Loss 0.649, Disc Loss 1.064
# Epoch 600: GAIL Loss 0.321, Disc Loss 0.696
# Epoch 610: GAIL Loss 0.341, Disc Loss 0.684
# Epoch 620: GAIL Loss 0.242, Disc Loss 0.642
# Epoch 630: GAIL Loss 0.478, Disc Loss 0.829
# Epoch 640: GAIL Loss 0.223, Disc Loss 0.671
# Epoch 650: GAIL Loss 0.238, Disc Loss 0.599
# Epoch 660: GAIL Loss 0.351, Disc Loss 0.785
# Epoch 670: GAIL Loss 0.278, Disc Loss 0.682
# Epoch 680: GAIL Loss 0.383, Disc Loss 0.747
# Epoch 690: GAIL Loss 0.239, Disc Loss 0.643
# Epoch 700: GAIL Loss 0.239, Disc Loss 0.584
# Epoch 710: GAIL Loss 0.279, Disc Loss 0.638
# Epoch 720: GAIL Loss 0.224, Disc Loss 0.585
# Epoch 730: GAIL Loss 0.279, Disc Loss 0.638
# Epoch 740: GAIL Loss 0.379, Disc Loss 0.752
# Epoch 750: GAIL Loss 0.282, Disc Loss 0.635
# Epoch 760: GAIL Loss 0.217, Disc Loss 0.607
# Epoch 770: GAIL Loss 0.204, Disc Loss 0.576
# Epoch 780: GAIL Loss 0.429, Disc Loss 0.807
# Epoch 790: GAIL Loss 0.446, Disc Loss 0.812
# Epoch 800: GAIL Loss 0.411, Disc Loss 0.772
# Epoch 810: GAIL Loss 0.243, Disc Loss 0.568
# Epoch 820: GAIL Loss 0.286, Disc Loss 0.629
# Epoch 830: GAIL Loss 0.407, Disc Loss 0.741
# Epoch 840: GAIL Loss 0.294, Disc Loss 0.704
# Epoch 850: GAIL Loss 0.292, Disc Loss 0.644
# Epoch 860: GAIL Loss 0.232, Disc Loss 0.598
# Epoch 870: GAIL Loss 0.249, Disc Loss 0.637
# Epoch 880: GAIL Loss 0.391, Disc Loss 0.786
# Epoch 890: GAIL Loss 0.213, Disc Loss 0.582
# Epoch 900: GAIL Loss 0.255, Disc Loss 0.595
# Epoch 910: GAIL Loss 0.232, Disc Loss 0.640
# Epoch 920: GAIL Loss 0.433, Disc Loss 0.771
# Epoch 930: GAIL Loss 0.615, Disc Loss 1.014
# Epoch 940: GAIL Loss 0.260, Disc Loss 0.592
# Epoch 950: GAIL Loss 0.504, Disc Loss 0.898
# Epoch 960: GAIL Loss 0.438, Disc Loss 0.750
# Epoch 970: GAIL Loss 0.549, Disc Loss 0.848
# Epoch 980: GAIL Loss 0.390, Disc Loss 0.711
# Epoch 990: GAIL Loss 0.166, Disc Loss 0.489
# Epoch 1000: GAIL Loss 0.464, Disc Loss 0.812
# Epoch 1010: GAIL Loss 0.435, Disc Loss 0.799
# Epoch 1020: GAIL Loss 0.209, Disc Loss 0.534
# Epoch 1030: GAIL Loss 0.392, Disc Loss 0.764
# Epoch 1040: GAIL Loss 0.550, Disc Loss 0.935
# Epoch 1050: GAIL Loss 0.222, Disc Loss 0.573
# Epoch 1060: GAIL Loss 0.292, Disc Loss 0.574
# Epoch 1070: GAIL Loss 0.184, Disc Loss 0.559
# Epoch 1080: GAIL Loss 0.417, Disc Loss 0.806
# Epoch 1090: GAIL Loss 0.184, Disc Loss 0.573
# Epoch 1100: GAIL Loss 0.217, Disc Loss 0.638
# Epoch 1110: GAIL Loss 0.251, Disc Loss 0.563
# Epoch 1120: GAIL Loss 0.234, Disc Loss 0.544
# Epoch 1130: GAIL Loss 0.383, Disc Loss 0.815
# Epoch 1140: GAIL Loss 0.257, Disc Loss 0.564
# Epoch 1150: GAIL Loss 0.255, Disc Loss 0.620
# Epoch 1160: GAIL Loss 0.217, Disc Loss 0.659
# Epoch 1170: GAIL Loss 0.192, Disc Loss 0.588
# Epoch 1180: GAIL Loss 0.225, Disc Loss 0.611
# Epoch 1190: GAIL Loss 0.205, Disc Loss 0.550
# Epoch 1200: GAIL Loss 0.206, Disc Loss 0.509
# Epoch 1210: GAIL Loss 0.294, Disc Loss 0.621
# Epoch 1220: GAIL Loss 0.299, Disc Loss 0.642
# Epoch 1230: GAIL Loss 0.193, Disc Loss 0.591
# Epoch 1240: GAIL Loss 0.390, Disc Loss 0.753
# Epoch 1250: GAIL Loss 0.195, Disc Loss 0.496
# Epoch 1260: GAIL Loss 0.339, Disc Loss 0.722
# Epoch 1270: GAIL Loss 0.286, Disc Loss 0.608
# Epoch 1280: GAIL Loss 0.279, Disc Loss 0.587
# Epoch 1290: GAIL Loss 0.183, Disc Loss 0.556
# Epoch 1300: GAIL Loss 0.216, Disc Loss 0.563
# Epoch 1310: GAIL Loss 0.305, Disc Loss 0.685
# Epoch 1320: GAIL Loss 0.227, Disc Loss 0.664
# Epoch 1330: GAIL Loss 0.198, Disc Loss 0.510
# Epoch 1340: GAIL Loss 0.560, Disc Loss 0.931
# Epoch 1350: GAIL Loss 0.168, Disc Loss 0.502
# Epoch 1360: GAIL Loss 0.218, Disc Loss 0.545
# Epoch 1370: GAIL Loss 0.230, Disc Loss 0.545
# Epoch 1380: GAIL Loss 0.235, Disc Loss 0.595
# Epoch 1390: GAIL Loss 0.477, Disc Loss 0.911
# Epoch 1400: GAIL Loss 0.351, Disc Loss 0.725
# Epoch 1410: GAIL Loss 0.207, Disc Loss 0.549
# Epoch 1420: GAIL Loss 0.422, Disc Loss 0.731
# Epoch 1430: GAIL Loss 0.147, Disc Loss 0.582
# Epoch 1440: GAIL Loss 0.249, Disc Loss 0.645
# Epoch 1450: GAIL Loss 0.306, Disc Loss 0.649
# Epoch 1460: GAIL Loss 0.229, Disc Loss 0.604
# Epoch 1470: GAIL Loss 0.212, Disc Loss 0.561
# Epoch 1480: GAIL Loss 0.195, Disc Loss 0.508
# Epoch 1490: GAIL Loss 0.209, Disc Loss 0.582
# Epoch 1500: GAIL Loss 0.303, Disc Loss 0.647
# Epoch 1510: GAIL Loss 0.188, Disc Loss 0.517
# Epoch 1520: GAIL Loss 0.132, Disc Loss 0.564
# Epoch 1530: GAIL Loss 0.308, Disc Loss 0.659
# Epoch 1540: GAIL Loss 0.356, Disc Loss 0.749
# Epoch 1550: GAIL Loss 0.181, Disc Loss 0.555
# Epoch 1560: GAIL Loss 0.393, Disc Loss 0.781
# Epoch 1570: GAIL Loss 0.260, Disc Loss 0.555
# Epoch 1580: GAIL Loss 0.218, Disc Loss 0.482
# Epoch 1590: GAIL Loss 0.251, Disc Loss 0.720
# Epoch 1600: GAIL Loss 0.230, Disc Loss 0.668
# Epoch 1610: GAIL Loss 0.185, Disc Loss 0.582
# Epoch 1620: GAIL Loss 0.159, Disc Loss 0.604
# Epoch 1630: GAIL Loss 0.159, Disc Loss 0.550
# Epoch 1640: GAIL Loss 0.298, Disc Loss 0.729
# Epoch 1650: GAIL Loss 0.137, Disc Loss 0.541
# Epoch 1660: GAIL Loss 0.185, Disc Loss 0.573
# Epoch 1670: GAIL Loss 0.150, Disc Loss 0.625
# Epoch 1680: GAIL Loss 0.162, Disc Loss 0.547
# Epoch 1690: GAIL Loss 0.349, Disc Loss 0.848
# Epoch 1700: GAIL Loss 0.449, Disc Loss 1.028
# Epoch 1710: GAIL Loss 0.216, Disc Loss 0.701
# Epoch 1720: GAIL Loss 0.229, Disc Loss 0.649
# Epoch 1730: GAIL Loss 0.166, Disc Loss 0.529
# Epoch 1740: GAIL Loss 0.152, Disc Loss 0.606
# Epoch 1750: GAIL Loss 0.277, Disc Loss 0.699
# Epoch 1760: GAIL Loss 0.201, Disc Loss 0.604
# Epoch 1770: GAIL Loss 0.254, Disc Loss 0.761
# Epoch 1780: GAIL Loss 0.214, Disc Loss 0.778
# Epoch 1790: GAIL Loss 0.172, Disc Loss 0.554
# Epoch 1800: GAIL Loss 0.142, Disc Loss 0.545
# Epoch 1810: GAIL Loss 0.209, Disc Loss 0.588
# Epoch 1820: GAIL Loss 0.127, Disc Loss 0.618
# Epoch 1830: GAIL Loss 0.221, Disc Loss 0.598
# Epoch 1840: GAIL Loss 0.193, Disc Loss 0.626
# Epoch 1850: GAIL Loss 0.133, Disc Loss 0.631
# Epoch 1860: GAIL Loss 0.682, Disc Loss 1.125
# Epoch 1870: GAIL Loss 0.193, Disc Loss 0.543
# Epoch 1880: GAIL Loss 0.141, Disc Loss 0.491
# Epoch 1890: GAIL Loss 0.369, Disc Loss 0.820
# Epoch 1900: GAIL Loss 0.369, Disc Loss 0.885
# Epoch 1910: GAIL Loss 0.213, Disc Loss 0.565
# Epoch 1920: GAIL Loss 0.545, Disc Loss 1.161
# Epoch 1930: GAIL Loss 0.179, Disc Loss 0.505
# Epoch 1940: GAIL Loss 0.148, Disc Loss 0.531
# Epoch 1950: GAIL Loss 0.237, Disc Loss 0.678
# Epoch 1960: GAIL Loss 0.364, Disc Loss 0.881
# Epoch 1970: GAIL Loss 0.171, Disc Loss 0.567
# Epoch 1980: GAIL Loss 0.227, Disc Loss 0.779
# Epoch 1990: GAIL Loss 0.160, Disc Loss 0.576
# Epoch 2000: GAIL Loss 0.164, Disc Loss 0.551
# Epoch 2010: GAIL Loss 0.269, Disc Loss 0.745
# Epoch 2020: GAIL Loss 0.249, Disc Loss 0.672
# Epoch 2030: GAIL Loss 0.222, Disc Loss 0.620
# Epoch 2040: GAIL Loss 0.216, Disc Loss 0.580
# Epoch 2050: GAIL Loss 0.365, Disc Loss 0.873
# Epoch 2060: GAIL Loss 0.159, Disc Loss 0.517
# Epoch 2070: GAIL Loss 0.292, Disc Loss 0.817
# Epoch 2080: GAIL Loss 0.138, Disc Loss 0.437
# Epoch 2090: GAIL Loss 0.235, Disc Loss 0.647
# Epoch 2100: GAIL Loss 0.153, Disc Loss 0.502
# Epoch 2110: GAIL Loss 0.155, Disc Loss 0.550
# Epoch 2120: GAIL Loss 0.124, Disc Loss 0.452
# Epoch 2130: GAIL Loss 0.148, Disc Loss 0.561
# Epoch 2140: GAIL Loss 0.269, Disc Loss 0.686
# Epoch 2150: GAIL Loss 0.255, Disc Loss 0.564
# Epoch 2160: GAIL Loss 0.240, Disc Loss 0.616
# Epoch 2170: GAIL Loss 0.253, Disc Loss 0.613
# Epoch 2180: GAIL Loss 0.287, Disc Loss 0.736
# Epoch 2190: GAIL Loss 0.159, Disc Loss 0.573
# Epoch 2200: GAIL Loss 0.198, Disc Loss 0.590
# Epoch 2210: GAIL Loss 0.320, Disc Loss 0.707
# Epoch 2220: GAIL Loss 0.277, Disc Loss 0.611
# Epoch 2230: GAIL Loss 0.166, Disc Loss 0.658
# Epoch 2240: GAIL Loss 0.187, Disc Loss 0.586
# Epoch 2250: GAIL Loss 0.126, Disc Loss 0.520
# Epoch 2260: GAIL Loss 0.139, Disc Loss 0.519
# Epoch 2270: GAIL Loss 0.187, Disc Loss 0.617
# Epoch 2280: GAIL Loss 0.249, Disc Loss 0.784
# Epoch 2290: GAIL Loss 0.132, Disc Loss 0.523
# Epoch 2300: GAIL Loss 0.166, Disc Loss 0.549
# Epoch 2310: GAIL Loss 0.189, Disc Loss 0.648
# Epoch 2320: GAIL Loss 0.174, Disc Loss 0.687
# Epoch 2330: GAIL Loss 0.197, Disc Loss 0.657
# Epoch 2340: GAIL Loss 0.246, Disc Loss 0.748
# Epoch 2350: GAIL Loss 0.193, Disc Loss 0.558
# Epoch 2360: GAIL Loss 0.136, Disc Loss 0.550
# Epoch 2370: GAIL Loss 0.197, Disc Loss 0.725
# Epoch 2380: GAIL Loss 0.128, Disc Loss 0.606
# Epoch 2390: GAIL Loss 0.104, Disc Loss 0.531
# Epoch 2400: GAIL Loss 0.313, Disc Loss 0.940
# Epoch 2410: GAIL Loss 0.258, Disc Loss 0.775
# Epoch 2420: GAIL Loss 0.195, Disc Loss 0.677
# Epoch 2430: GAIL Loss 0.154, Disc Loss 0.524
# Epoch 2440: GAIL Loss 0.161, Disc Loss 0.622
# Epoch 2450: GAIL Loss 0.153, Disc Loss 0.622
# Epoch 2460: GAIL Loss 0.086, Disc Loss 0.454
# Epoch 2470: GAIL Loss 0.161, Disc Loss 0.549
# Epoch 2480: GAIL Loss 0.263, Disc Loss 0.667
# Epoch 2490: GAIL Loss 0.127, Disc Loss 0.577
# Epoch 2500: GAIL Loss 0.277, Disc Loss 0.832
# Epoch 2510: GAIL Loss 0.157, Disc Loss 0.559
# Epoch 2520: GAIL Loss 0.242, Disc Loss 0.699
# Epoch 2530: GAIL Loss 0.308, Disc Loss 0.749
# Epoch 2540: GAIL Loss 0.173, Disc Loss 0.588
# Epoch 2550: GAIL Loss 0.173, Disc Loss 0.616
# Epoch 2560: GAIL Loss 0.237, Disc Loss 0.611
# Epoch 2570: GAIL Loss 0.124, Disc Loss 0.565
# Epoch 2580: GAIL Loss 0.142, Disc Loss 0.629
# Epoch 2590: GAIL Loss 0.212, Disc Loss 0.701
# Epoch 2600: GAIL Loss 0.126, Disc Loss 0.562
# Epoch 2610: GAIL Loss 0.123, Disc Loss 0.574
# Epoch 2620: GAIL Loss 0.239, Disc Loss 0.854
# Epoch 2630: GAIL Loss 0.110, Disc Loss 0.611
# Epoch 2640: GAIL Loss 0.163, Disc Loss 0.696
# Epoch 2650: GAIL Loss 0.199, Disc Loss 0.649
# Epoch 2660: GAIL Loss 0.091, Disc Loss 0.571
# Epoch 2670: GAIL Loss 0.099, Disc Loss 0.567
# Epoch 2680: GAIL Loss 0.143, Disc Loss 0.670
# Epoch 2690: GAIL Loss 0.169, Disc Loss 0.554
# Epoch 2700: GAIL Loss 0.185, Disc Loss 0.683
# Epoch 2710: GAIL Loss 0.120, Disc Loss 0.500
# Epoch 2720: GAIL Loss 0.137, Disc Loss 0.577
# Epoch 2730: GAIL Loss 0.202, Disc Loss 0.743
# Epoch 2740: GAIL Loss 0.123, Disc Loss 0.575
# Epoch 2750: GAIL Loss 0.131, Disc Loss 0.641
# Epoch 2760: GAIL Loss 0.119, Disc Loss 0.536
# Epoch 2770: GAIL Loss 0.081, Disc Loss 0.594
# Epoch 2780: GAIL Loss 0.236, Disc Loss 0.698
# Epoch 2790: GAIL Loss 0.136, Disc Loss 0.615
# Epoch 2800: GAIL Loss 0.124, Disc Loss 0.613
# Epoch 2810: GAIL Loss 0.190, Disc Loss 0.700
# Epoch 2820: GAIL Loss 0.210, Disc Loss 0.813
# Epoch 2830: GAIL Loss 0.213, Disc Loss 0.738
# Epoch 2840: GAIL Loss 0.111, Disc Loss 0.552
# Epoch 2850: GAIL Loss 0.209, Disc Loss 0.813
# Epoch 2860: GAIL Loss 0.133, Disc Loss 0.568
# Epoch 2870: GAIL Loss 0.105, Disc Loss 0.580
# Epoch 2880: GAIL Loss 0.101, Disc Loss 0.472
# Epoch 2890: GAIL Loss 0.116, Disc Loss 0.532
# Epoch 2900: GAIL Loss 0.116, Disc Loss 0.675
# Epoch 2910: GAIL Loss 0.161, Disc Loss 0.649
# Epoch 2920: GAIL Loss 0.112, Disc Loss 0.573
# Epoch 2930: GAIL Loss 0.239, Disc Loss 0.801
# Epoch 2940: GAIL Loss 0.256, Disc Loss 0.724
# Epoch 2950: GAIL Loss 0.123, Disc Loss 0.514
# Epoch 2960: GAIL Loss 0.096, Disc Loss 0.548
# Epoch 2970: GAIL Loss 0.165, Disc Loss 0.747
# Epoch 2980: GAIL Loss 0.075, Disc Loss 0.545
# Epoch 2990: GAIL Loss 0.098, Disc Loss 0.577

# %% [markdown]
# Протестируйте ваш алгоритм

# %%
for episode in range(10):
    obs, _ = env.reset()  # Получаем начальное состояние (игнорируем info)
    done = False
    total_reward = 0
    t = 0  # Временная метка

    while not done:
        # Добавляем sin(t) и cos(t) к состоянию
        augmented_obs = np.append(obs, [np.sin(t), np.cos(t)])
        
        # Преобразуем состояние в тензор
        obs_tensor = torch.tensor(augmented_obs, dtype=torch.float32).unsqueeze(0)
        
        # Получаем действие от политики
        action = policy.get_action(obs_tensor)
        
        # Совершаем шаг в среде
        next_obs, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        
        # Обновляем состояние и награду
        obs = next_obs
        total_reward += reward
        t += 1

    print(f"Episode {episode + 1}: Total Reward = {total_reward}")
env.close()
# Out:
# Episode 1: Total Reward = -200.0
# Episode 2: Total Reward = -200.0
# Episode 3: Total Reward = -200.0
# Episode 4: Total Reward = -200.0
# Episode 5: Total Reward = -200.0
# Episode 6: Total Reward = -200.0
# Episode 7: Total Reward = -200.0
# Episode 8: Total Reward = -200.0
# Episode 9: Total Reward = -200.0
# Episode 10: Total Reward = -200.0
